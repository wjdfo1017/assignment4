# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import io
import urllib

url="https://earthquake.usgs.gov/fdsnws/event/1/query?format=csv&starttime=2016-01-01&endtime=2017-01-02&minmagnitude=4"
url_open = urllib.request.urlopen(url)
df=pd.read_csv(io.StringIO(url_open.read().decode('utf-8')), delimiter=',')

url2="https://earthquake.usgs.gov/fdsnws/event/1/query?format=csv&starttime=2017-01-02&endtime=2018-01-02&minmagnitude=4"
url_open2 = urllib.request.urlopen(url2)
df2=pd.read_csv(io.StringIO(url_open2.read().decode('utf-8')), delimiter=',')

url3="https://earthquake.usgs.gov/fdsnws/event/1/query?format=csv&starttime=2018-01-02&endtime=2019-01-02&minmagnitude=4"
url_open3 = urllib.request.urlopen(url3)
df3=pd.read_csv(io.StringIO(url_open3.read().decode('utf-8')), delimiter=',')
new_csv=pd.concat([df, df2,df3])

url4="https://earthquake.usgs.gov/fdsnws/event/1/query?format=csv&starttime=2019-01-02&endtime=2019-10-02&minmagnitude=4"
url_open4 = urllib.request.urlopen(url4)
df4=pd.read_csv(io.StringIO(url_open4.read().decode('utf-8')), delimiter=',')
new_csv=pd.concat([df, df2,df3,df4])

new_csv.fillna(0)
# Out:
#                           time  latitude  longitude   depth  mag magType  nst  \
# 0     2017-01-01T22:58:01.580Z    3.9731    94.5977   30.62  4.6      mb  0.0
# 1     2017-01-01T22:49:29.850Z  -22.3853   171.4833  100.79  4.6      mb  0.0
# 2     2017-01-01T22:06:44.630Z   36.5673    71.4740  107.00  4.2      mb  0.0
# 3     2017-01-01T21:35:54.460Z    3.7216   128.7148   10.00  4.4      mb  0.0
# 4     2017-01-01T21:30:23.010Z  -10.3123   161.4198   58.73  4.7      mb  0.0
# ...                        ...       ...        ...     ...  ...     ...  ...
# 9883  2019-01-02T06:48:43.541Z   58.3343  -153.1447   61.80  4.9      ml  0.0
# 9884  2019-01-02T04:30:30.120Z  -12.7763    45.4543   10.00  4.6      mb  0.0
# 9885  2019-01-02T03:49:08.290Z   15.3995   -94.7155   35.00  4.1      mb  0.0
# 9886  2019-01-02T03:12:54.750Z   42.4859   104.4129   10.00  5.0      mb  0.0
# 9887  2019-01-02T00:01:59.590Z   13.1406   121.2786   35.00  4.5      mb  0.0
#
#         gap   dmin   rms  ...                   updated  \
# 0     176.0  2.653  0.42  ...  2017-03-27T23:53:17.040Z
# 1     119.0  3.329  0.41  ...  2017-03-27T23:53:17.040Z
# 2      72.0  0.910  0.72  ...  2017-03-27T23:53:17.040Z
# 3     124.0  3.224  0.89  ...  2017-03-27T23:53:17.040Z
# 4     189.0  1.690  0.59  ...  2017-03-27T23:53:17.040Z
# ...     ...    ...   ...  ...                       ...
# 9883    0.0  0.000  0.95  ...  2019-03-08T17:50:13.040Z
# 9884  111.0  5.998  0.52  ...  2019-03-08T17:50:21.040Z
# 9885  163.0  1.391  0.96  ...  2019-03-08T17:50:13.040Z
# 9886   41.0  5.693  0.33  ...  2019-03-08T17:50:13.040Z
# 9887  135.0  8.374  0.67  ...  2019-03-08T17:50:20.040Z
#
#                                         place        type horizontalError  \
# 0              170km W of Meulaboh, Indonesia  earthquake             8.2
# 1         58km W of Ile Hunter, New Caledonia  earthquake            11.3
# 2          13km SSW of Ashkasham, Afghanistan  earthquake             5.1
# 3              233km NNE of Tobelo, Indonesia  earthquake            10.4
# 4       57km WNW of Kirakira, Solomon Islands  earthquake            15.8
# ...                                       ...         ...             ...
# 9883       71km NNW of Kodiak Station, Alaska  earthquake             0.0
# 9884              18km E of Pamandzi, Mayotte  earthquake             7.4
# 9885  92km S of San Francisco del Mar, Mexico  earthquake             5.7
# 9886      71km WSW of Sangiyn Dalay, Mongolia  earthquake             7.3
# 9887           4km S of Victoria, Philippines  earthquake             6.9
#
#      depthError  magError  magNst    status  locationSource magSource
# 0           5.5     0.083    44.0  reviewed              us        us
# 1          10.6     0.122    20.0  reviewed              us        us
# 2           4.0     0.108    24.0  reviewed              us        us
# 3           1.9     0.170    10.0  reviewed              us        us
# 4          11.1     0.101    30.0  reviewed              us        us
# ...         ...       ...     ...       ...             ...       ...
# 9883        0.2     0.000     0.0  reviewed              ak        ak
# 9884        1.9     0.193     8.0  reviewed              us        us
# 9885        2.0     0.088    35.0  reviewed              us        us
# 9886        1.9     0.044   163.0  reviewed              us        us
# 9887        2.0     0.121    20.0  reviewed              us        us
#
# [53012 rows x 22 columns]
